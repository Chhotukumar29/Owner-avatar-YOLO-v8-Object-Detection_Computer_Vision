# %%
# !nvidia-smi
# Out:
# Thu Aug  8 14:39:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Models:
# train, val, predict
#
# # Tasks:
# detect, segment, classify
#
# # Data:
# Format can be differ for task type, Supports data.yaml, data_folder, data_name

# %% [markdown]
# # Installtion
#
# Pip install the ultralytics package including all requirements in a Python>=3.8 environment with PyTorch>=1.8.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
! pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %% [markdown]
# # CMD

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 1. Detection
#
# ### **CLI**
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a yolo command:

# %%
# !yolo predict model=yolov8n.pt source='/content/Images/1.jpg'
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Images/1.jpg: 448x640 1 person, 1 suitcase, 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 605.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Segmentation

# %%
# !yolo predict model=yolov8n-seg.pt source='/content/Images/1.jpg'
# Out:
# ...
# 100% 6.74M/6.74M [00:00<00:00, 115MB/s]
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/Images/1.jpg: 448x640 1 person, 10 suitcases, 87.3ms
# Speed: 2.5ms preprocess, 87.3ms inference, 683.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Python Script

# %%
from ultralytics import YOLO

# Load a segmentation model
model = YOLO('yolov8n-seg.pt')  # load an official model
model.predict(source='/content/Images/1.jpg', save=True)
# Out:
# image 1/1 /content/Images/1.jpg: 448x640 1 person, 10 suitcases, 86.3ms
# Speed: 2.9ms preprocess, 86.3ms inference, 703.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %% [markdown]
# # Classification

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="/content/Images/1.jpg"
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 21.8MB/s]
# image 1/1 /content/Images/1.jpg: 224x224 dumbbell 0.32, switch 0.06, traffic_light 0.05, power_drill 0.04, guillotine 0.03, 2.8ms
# Speed: 40.7ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
